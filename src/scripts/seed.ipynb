# %% [markdown]
# # Consulta simples com Sqlalcheme

# %%
from sqlalchemy import text
from sqlalchemy.ext.asyncio import create_async_engine, AsyncSession
from sqlalchemy import Table, Column, MetaData, select, String, Boolean
from sqlalchemy.orm import sessionmaker

DATABASE_URL = "postgresql+asyncpg://user:password@localhost/products_db"

engine = create_async_engine(DATABASE_URL, echo=True)
async_session = sessionmaker(engine, class_=AsyncSession, expire_on_commit=False)


# Definindo manualmente a tabela do sistema
metadata = MetaData()
pg_database = Table(
    "pg_database",
    metadata,
    Column("datname", String),
    Column("datistemplate", Boolean),
    schema="pg_catalog",  # importante: schema correto
)

# Criando o select
stmt = select(pg_database.c.datname).where(pg_database.c.datistemplate == False)


async def list_databases():
    async with async_session() as session:
        result = await session.execute(stmt)
        databases = [row[0] for row in result.fetchall()]
        return databases


async def list_databases_text():
    async with async_session() as session:
        result = await session.execute(
            text("SELECT datname FROM pg_database WHERE datistemplate = false;")
        )
        databases = [row[0] for row in result.fetchall()]
        return databases


async def list_tables():
    async with async_session() as session:
        result = await session.execute(
            text(
                "SELECT tablename FROM pg_catalog.pg_tables WHERE schemaname = 'public';"
            )
        )
        tables = [row[0] for row in result.fetchall()]
        return tables


# Exemplo de uso (em ambiente async):
# import asyncio
# print(asyncio.run(list_tables()))

print(await list_tables())
print(await list_databases())

# %%
import uuid
from sqlalchemy import Column, String, Numeric, Boolean, DateTime, Index
from sqlalchemy.dialects.postgresql import UUID
from sqlalchemy.orm import declarative_base
from sqlalchemy.sql import func

Base = declarative_base()


class Product(Base):
    __tablename__ = "products"

    id = Column(UUID(as_uuid=True), primary_key=True, default=uuid.uuid4)
    name = Column(String, nullable=False)
    description = Column(String)
    price = Column(Numeric(10, 2), nullable=False)
    in_stock = Column(Boolean, default=True)
    created_at = Column(DateTime, server_default=func.now())

    __table_args__ = (
        Index("idx_products_name", "name"),
        Index("idx_products_price", "price"),
    )

# %% [markdown]
# ### Seed para popular o banco

# %%
from faker import Faker
from sqlalchemy.ext.asyncio import create_async_engine, AsyncSession
from sqlalchemy.orm import sessionmaker
from sqlalchemy.dialects.postgresql import insert

fake = Faker()


async def seed_data():
    """Seed the database with sample product data."""
    async with async_session() as session:  # type: AsyncSession
        products = []
        for _ in range(100):
            products.append(
                {
                    "name": fake.name(),
                    "description": fake.text(),
                    "price": fake.random_number(digits=2),
                    "in_stock": fake.boolean(),
                }
            )

        await session.execute(insert(Product), products)
        await session.commit()


if __name__ == "__main__":
    # asyncio.run(seed_data())
    await seed_data()

# %% [markdown]
# ### SELECT na tabela products

# %%
from sqlalchemy import Select
from sqlalchemy import Table, Column, String, Numeric, Boolean, DateTime, MetaData
from sqlalchemy.dialects.postgresql import UUID
from sqlalchemy.sql import func


products = Table(
    "products",
    metadata,
    Column("id", UUID(as_uuid=True), primary_key=True),
    Column("name", String, nullable=False),
    Column("description", String),
    Column("price", Numeric(10, 2), nullable=False),
    Column("in_stock", Boolean, default=True),
    Column("created_at", DateTime, server_default=func.now()),
)

stmt = Select(products).where(products.c.price > 50)

print(stmt.compile(dialect=engine.dialect))  # Exibe a consulta SQL gerada
# Out:
# SELECT products.id, products.name, products.description, products.price, products.in_stock, products.created_at
# FROM products
# WHERE products.price > $1::INTEGER

# %%
from sqlalchemy import Table, MetaData, select


products = Table(
    "products", metadata, autoload_with=engine
)  # Usa introspecção do banco

stmt = select(products)  # Equivalente a SELECT * FROM products


async def list_products():
    async with async_session() as session:
        result = await session.execute(stmt)
        rows = result.fetchall()
        return rows


for row in await list_products():
    print(row)
# --- IGNORE ---
# Out:
# 2025-10-21 18:33:49,860 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-21 18:33:49,866 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.description, products.price, products.in_stock, products.created_at
# FROM products
# 2025-10-21 18:33:49,867 INFO sqlalchemy.engine.Engine [cached since 83.34s ago] ()
# 2025-10-21 18:33:49,915 INFO sqlalchemy.engine.Engine ROLLBACK
# (UUID('2d0e82af-34c0-47a0-8b8b-9e90939b2fe6'), 'Taylor Atkins', 'Almost employee imagine car beautiful detail do spend. Information look represent natural moment better truth. Represent each guy site woman. Much product rather.', Decimal('70.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('4b284d34-6f41-4ad8-9134-269bb88ab56f'), 'Christina Chapman', 'Many sit marriage arm start. End able resource. Expect lose big lose property similar.', Decimal('43.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('659447b6-97e6-46d6-8a64-7eb9e4fee93f'), 'Haley Peters', 'Statement effort bit. Foot start offer edge everybody. Man its so plan Congress.', Decimal('47.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('bd7e5377-5804-44cd-8bd2-a632f52520cf'), 'Lindsay Odonnell', 'Usually computer itself TV.\nStock vote important product treat phone. What best experience own.\nEasy traditional fill stay become. Chair responsibility dark. Speak attention son response there news.', Decimal('26.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('6629a7a3-1123-42bf-b98f-169cd357a988'), 'Kevin Boyle', 'Toward me animal huge determine wait possible. Choice summer wear water early young. Use trade edge paper stay.', Decimal('94.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('656aa9c1-e918-412f-8638-d1e9b519f701'), 'William Washington', 'Past black story article. Soldier value center space evidence.\nSeat federal sell receive glass week. Local behind friend. Include usually old house rich far number.\nPrevent of across personal.', Decimal('25.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('bee85507-6a81-46e0-ad19-60ea8fe8c9dd'), 'Katelyn Hobbs', 'Can water to go onto treatment. Off contain scene employee lot available often lead.\nGun lose upon way start ever even billion. Paper staff bad find.\nWind side expect message yes lose.', Decimal('50.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('41b5fa57-853b-4033-90d7-9a00ffddd031'), 'John Foster', 'Memory about probably husband PM image painting page. Ability indicate office matter too former. Firm remember room long cost mother safe recent. Actually and series doctor plant international.', Decimal('9.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('c5dc8dac-5183-4503-8f81-f5392c48798c'), 'Sydney Gutierrez', 'Ok loss find spring enter less election effort. Instead president red. More purpose build. Piece now marriage performance break participant.\nSerious religious year he. Us do ready wind they act for.', Decimal('75.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('6f085366-6b12-4b05-a0af-d6053d12e2b3'), 'Joshua Wood', 'Since international wish ask stuff. Might really indicate. Here court final official ten.\nModern no resource guy. Join federal six team house budget. Store organization step hour.', Decimal('9.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('d2fbdf07-2d38-4395-b4bb-016eda643504'), 'Reginald Smith', 'Enough top authority hope fund attorney commercial. Could hotel management party suggest those federal. One themselves clearly with share.', Decimal('73.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('26632fd9-8700-405e-9aad-8e4f805e856e'), 'Jennifer Stokes', 'Employee show human. Water stuff eye prove success hand help. Reveal may control arrive.\nDifference both move follow nice democratic address. Today business design leg moment.', Decimal('92.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('4e15ef92-076f-4c74-a992-9db3c845959f'), 'Dale Sparks', 'Factor ready share. Such hotel charge recent.\nSea rest exist possible. Ask idea well seat. Your him set other artist.\nYear recent reveal writer beautiful. Against onto product budget.', Decimal('5.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('41c159d0-307f-41c5-ba3c-10751a20e362'), 'Nicole Griffin', 'Book I few oil important show business type.', Decimal('65.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('b9dc250c-2d95-439f-8f21-c2aca93e1851'), 'Justin Carter', 'Religious science we mention southern shoulder.\nGive speech skill believe type social level. Myself past moment stuff quickly old.', Decimal('53.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('16c4dbdf-748a-44a6-89fd-ed53a4da32ca'), 'Dustin Haas', 'Matter happy society southern although him. Nature feeling event establish city economic and.\nFederal big actually realize draw bank security nothing. Agency business sure evidence difficult.', Decimal('37.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('e550b156-9bb6-4d74-9fb4-b63cbe780639'), 'Ronald Cook', 'Anything continue car run first. Task actually group water fill professor be. Also she food mother baby fight use. Body present animal effect agent admit.', Decimal('36.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('d4535f1f-2ef5-4a6a-9127-83195e1e6cd6'), 'Alexis Brooks', 'Experience major left whom world our watch. Only chance suffer method.\nSpecific voice message value quite area. Apply one way but second. Leader position should black significant beyond happen data.', Decimal('99.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('5818e3d2-8912-40f4-80c7-35965372d289'), 'Jeffrey Sanchez', 'Lay possible measure word. Authority risk need color.\nAllow reduce study animal way at sign. Attorney event assume stand perform call than draw. Blue control child its religious author.', Decimal('91.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('10866ed9-2a9d-4dd0-9672-84a5e956e419'), 'Michelle Freeman', 'Include special behind near certain institution. Sport which special forward science attorney. Have different country travel program.', Decimal('23.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('c61db4ce-5611-434f-86dd-4a17f3867c17'), 'James Sanchez', 'Card hear turn four they. Hospital because star whole.\nYet seat wife interesting room stock report alone. Time actually beyond energy own choose toward outside.', Decimal('27.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('8c436ed1-a34e-499e-9436-f4793ef4d3b3'), 'Shirley Lopez', 'Ask explain hour. Who seek during style name. Place send spring organization certainly major.\nWe blue red say.\nIt add beautiful look similar southern election able. When fire decide main.', Decimal('24.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('4eb11ab0-a240-4b56-a13d-de2f1bb5ffee'), 'John Moody', 'Sister minute reduce common military morning.\nParty as course. Fish your avoid term institution baby.', Decimal('42.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('bd345562-2d45-4ed3-9ca0-0aabb17a6004'), 'Carl Watson', 'High question ability cold represent think. Network book skill.\nProcess source day smile west campaign if spend. Whatever firm space condition. Mr anything girl assume free always direction.', Decimal('93.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('79fe1679-b564-44b3-9d7f-d4b8e9564492'), 'Samuel Webb', 'Process we difficult.', Decimal('40.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('f1ebe3cb-8532-471a-bfc9-71772628016c'), 'Michael Marshall', 'Box cut across whatever. Same tax both must building enough hope save. Some car themselves collection major.\nSimilar suffer car win. Set majority possible away become else member. Mr final success.', Decimal('93.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('58ea9caa-781e-46e0-bcc1-c70f5ec31e78'), 'David Werner', 'Different low better home hard health. Check concern traditional total practice.\nWill difference party direction. Concern all check soldier compare say.', Decimal('94.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('1842a0ab-28d5-4260-9088-f6bc417b9bcc'), 'Sabrina Martin', 'Production area run couple. Population the commercial career. Guy peace stay you.\nLot last small. Business art page measure value place.', Decimal('73.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('79751073-c586-47b7-9430-15acc74513cc'), 'Kenneth Harris PhD', 'Court international hard learn matter policy rate. Red simply list leg base add exactly. Across nothing exist budget know value.\nGame wrong these. Adult eat final three. Piece career card sing use.', Decimal('5.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('21cd0d91-5d1a-45d3-b018-df4405856c00'), 'Jose Stanton', 'Trouble election few fear finally. Design society seek few seat reflect after.\nOr act today garden. Well whether majority collection next wish executive.', Decimal('70.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('d6f9ced5-9dfc-4bc1-9480-2a03fc8329d8'), 'Samuel Mitchell', 'Who heavy compare worker entire tax bit technology. Front discussion police it. Win others alone also my follow prevent.', Decimal('49.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('9a6074fc-6980-4c8a-a0b5-c457ab261888'), 'Darren Briggs', 'Same receive I political say administration. Rather suddenly agent alone girl.\nBetter adult society three sense. Life rise teacher personal four. Run everybody already sister both per.', Decimal('23.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('338fdd41-c931-4434-a689-b6ca44a9389e'), 'Manuel Dean', 'Social wide because run. Strong bad agency treatment budget travel wonder.\nBank sound along but must recognize carry. Relationship cold send hope create husband.', Decimal('94.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('35e9d18e-fc80-4ae7-90ae-a3377ef2f697'), 'David Williamson', 'Land paper leader station price want fly situation. Land bad story decide growth. Partner strong want else factor.\nState sea bar. Record against growth protect specific art can.', Decimal('87.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('62df5fa9-92fb-45d3-b7b1-f8110da22b42'), 'Victoria Lynch', 'Program possible thus pattern identify. Major forget become industry let school make.\nPopulation account beat eat risk. Happy race kitchen product. Example alone Republican generation.', Decimal('83.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('d79fff74-595d-4467-91f7-37bebd834b65'), 'Michael Cobb', 'Focus conference out visit see why keep.\nSkill bag where city full whatever hundred. Risk fear write.', Decimal('45.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('615e9193-11f4-4d93-bc42-a7ec5301638b'), 'Michelle Lee', 'Lot ability arrive apply human. Training former change several push so picture. Present successful newspaper base turn close.', Decimal('91.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('9187ca76-8760-4d33-bba3-b5bf19f50f89'), 'Jimmy Martin', 'Mother business lawyer we television have low. She place yard develop well cultural.\nAnswer become Democrat upon I since religious. Form protect give keep. According account give bag story week all.', Decimal('96.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('6b476c1e-ac30-4bcb-81e6-05e53a9840d8'), 'Rebecca Phillips', 'Glass free fight because federal address. Education brother add rest industry lot certain.\nAttention keep down almost beat. Yard grow suffer.', Decimal('92.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('090feb93-5222-4b59-8daa-92f4af0238de'), 'Rebecca Hughes', 'Pattern challenge central society ask. Again perhaps power size course response.\nTotal difficult sing TV service. Deep easy you another two actually.', Decimal('27.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('4f8a60d2-868f-4d7c-b4a4-a3842e48f21c'), 'David Clements', 'Pay world join but race product report point. Role figure role young.', Decimal('2.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('f29918c2-9388-4e4b-937b-6fe1655e641b'), 'Nichole Carter', 'Involve upon tough discover. Religious relationship law agency magazine skill. Outside lead hot western hotel chance.\nThat can second share together show. Your sign win word late purpose.', Decimal('10.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('9e71e525-5ded-4ac8-9e8c-2aa4b74f65f4'), 'Steven Cook', 'Question these participant when attention.', Decimal('87.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('ab680f64-472e-4d72-b399-1ed8d120e7ec'), 'David Mueller', 'Continue today also continue near region receive hope. Word rise also family ten word. Fast behavior own maintain leader.\nIndustry necessary method understand. Day college article whether not.', Decimal('97.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('05bde673-877f-401e-8276-179a446c9f39'), 'Wendy Thomas', 'Them suddenly against could. Pass year such office practice inside theory bill.\nUsually quickly customer lose. Live chance reach piece. Enough spring school tough contain.', Decimal('81.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('d3058706-aab3-4012-b72c-46b775b32755'), 'Jose Williams', 'Fight wait close. Behind example important make pay. Social arrive moment month.\nSort heart close series. That huge good door teach site. Body may interview wait already democratic.', Decimal('97.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('b3ec0694-e82b-4a93-ab95-40cb153a42fa'), 'Amy Bradley', 'Trade factor difference kid today. Administration short new green relate. None research practice just kitchen professional. Computer phone morning.\nUp blood office morning.', Decimal('88.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('aa9d28db-2ac1-4252-8813-fd963852693f'), 'Sheena Smith', 'Avoid from cell prepare voice type. Film than high beyond food section. Candidate authority describe cell between.', Decimal('38.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('ccdbbdc7-af79-4604-ad56-291d79358e5b'), 'Jeffrey Quinn', 'Mr boy morning explain. Then direction feel something couple. Choose big people network former.\nBaby share do agent personal tend work. Tough shake him network. Management north item.', Decimal('50.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('006fb773-0134-4d7a-b7c0-3e4d605b3b6b'), 'Gary Mccoy', 'Spend shake change. Someone side above present save mouth range. Figure do try must want everyone ground top.', Decimal('7.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('bc6b322a-88ad-4b80-9239-79a54530a710'), 'Zachary Miller', 'Sign factor plan. Miss car eat six leader young subject. Improve serious analysis these.', Decimal('7.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('ddc0bd60-7e74-410d-97b4-c84640e2ca05'), 'Megan Roberts DDS', 'Effect expert season yes kind everything. Time behavior necessary decide.\nCenter other according law gas beautiful. Consumer skill right north.', Decimal('87.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('47699e00-4559-4386-bb06-307648a013de'), 'Angela Mitchell', 'Your political certainly policy try father. Everything unit system weight together all. Remain resource page loss here. Radio off TV per federal art.', Decimal('13.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('6f440739-6cef-4e63-a312-0e3925e703af'), 'Roy Hall', 'Common accept recently also. Sound from in decide.\nMillion discover gas reason democratic game task crime. All kitchen paper. Race support identify red single until north page.', Decimal('97.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('c2447d36-e5da-4370-a7e1-0c10ff9b7c58'), 'Sherri Romero', 'Challenge practice material dinner. Different movie war country feeling box woman. Never executive suggest scientist whole approach.', Decimal('36.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('e57aa564-9091-41d0-b602-cb4a4b1c7a17'), 'Kelly Cooper', 'Successful into successful government whom. As ball forget bar card election.\nExample nature upon spring yourself specific. Analysis pattern moment special later late behavior foot.', Decimal('93.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('090e4920-b3c1-4d70-bee7-7a3e823d497c'), 'Matthew Rojas', 'Different voice ground only treatment. Voice physical call side. Reach sure whom series move continue themselves. Interest table throughout message care front few.', Decimal('4.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('9b28327e-fdcc-4642-a682-3f165bb61a43'), 'Mary Morgan', 'Structure laugh involve draw mother. Window as management enter high represent. High floor that rich then program.', Decimal('62.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('a79c46c6-5e81-429c-ad52-e2a98f2a7a3a'), 'Kellie Kent', 'Realize clearly line base even. Act hair type firm its staff old. Shake give now against.\nAge back environment tough eye line indicate. Reality less its trip floor.', Decimal('22.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('04678231-683b-4838-ba45-cc3ea91fe923'), 'Christopher Dickerson', 'Hotel manager person ahead should voice capital. Culture material professional poor world learn offer only. Guy painting sport possible west service structure. Social own watch be.', Decimal('42.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('13cd5560-3da3-4b9a-8fc1-4f1d0708e108'), 'Robert Skinner', 'Life future value heart wife political gas. Seek tell born sing its mean.\nCurrent ever those take give. Yet eye there bad suggest big cost.', Decimal('64.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('fe43d5bc-d1ef-4226-9e09-f52baa2f186d'), 'Russell Huber', 'Top stop maybe pay far. Individual short take eat chance simple.\nPlayer time live until civil. Card real require street. Mr choose scene evening color.', Decimal('96.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('4d1431cd-be48-4efd-83b2-20c05c9a7e68'), 'Chad Peterson', 'Entire environment nor hour. Realize painting activity force pretty idea. Agency adult necessary explain detail baby. War environment second capital leave practice protect.', Decimal('5.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('293e2cce-ba0d-4bd2-82b7-ffa866babc9b'), 'Janet Hayes', 'Month tell break window do stock staff those. Position some per report leg single. Light process bed strategy campaign.\nOccur player other capital produce. Century word book future sport along.', Decimal('26.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('26d4a1e5-4d4f-4442-bfea-23e9bce68c0b'), 'Kimberly Gibson', 'Information they draw single describe point. Test long compare support.\nInvolve share quickly decade federal start.\nAsk them other. Site per yes stay. Most professor just sister stand.', Decimal('50.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('732823e8-c06f-4f43-948b-3a1c5848b714'), 'Gregory Smith', 'Agree by full which write still especially. Rich return within add hope.\nLeast sure middle size individual its. Prove mission finish any positive.', Decimal('11.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('64352d29-fa63-41cd-8774-408df0a0e0a6'), 'Hunter Vargas', 'Line treat produce national ball sing. Kind use matter.\nCountry fish fill me reflect. Player possible yard energy low until indeed.\nPrice specific cell such up. Range security physical time that you.', Decimal('28.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('08d416f2-2eaa-450a-8f28-187aeae4ae89'), 'Jason Howard', 'Word necessary more million send member. With price determine.', Decimal('90.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('4263d9a3-673a-4306-aa9e-27070c951669'), 'Mr. Christopher Morris', 'From research wear style prevent wonder plant. Six build hundred expect style than. First same late hotel know name.', Decimal('84.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('4a318444-36f1-444c-ba7e-8778a8735245'), 'Heather Campbell', 'Compare side research issue even perhaps stage skill.\nLot general forward figure way return themselves. Fire better unit evidence cover. Show practice dream continue.', Decimal('44.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('1debe142-67f8-4ded-ac10-12da04889c4b'), 'Emily Wagner', 'Public because Democrat already eight great information. Ready simply chair board listen parent.\nThere station work. Whatever local to type crime.', Decimal('81.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('f0cbfcd1-44ed-4ff2-8d28-f0f76cbd541b'), 'Dr. John Henson', 'Offer table cause lawyer play matter.\nProduction attention unit fill why story every. Shake ask husband major. Guess stuff moment section thus pay. However dinner likely kid reveal.', Decimal('14.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('a502f0ce-f2a2-4bf3-aedb-0de0c7d0ee34'), 'Jamie Hebert', 'Summer tonight feeling prevent tell. Nothing candidate professor weight. Foreign many but itself.', Decimal('18.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('74d0b948-a4f7-46af-84d0-57f8006efe8d'), 'Carlos Becker', 'Marriage issue must why skill than majority. Keep five party claim behind parent which. Soon home onto total just.', Decimal('40.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('14242beb-f6ff-4c96-87d5-994ff75d36b4'), 'Carrie Wright', 'Require quite scene value serious issue. Bed when happy. She magazine animal red which.\nDemocratic agent example. Quickly section say fire.', Decimal('13.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('e28ae4c0-2c16-458b-a71a-717f3e138c91'), 'Nicholas Vargas', 'Set environment prepare already high us sea play. Break whatever through quickly.\nFight anyone miss sort lose prevent. Laugh technology style. Main attack interest speak knowledge give increase land.', Decimal('40.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('ed230b12-8a29-4f82-abf8-938c2ccabefd'), 'Lauren Yang', 'Test raise we. Control new live goal down today forward. Necessary gas current sure.\nField home however. Able defense owner agree fire. Let authority source until age catch cultural.', Decimal('89.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('a44caf9b-698b-4b83-9613-f4a6c531c11f'), 'Alicia Martinez', 'Group election use police I. Usually appear everyone drop floor.\nMany similar serious even. Tough wait food son information why.', Decimal('32.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('ae0ac861-3151-4007-9aa5-90bb35351165'), 'Shirley Rivera', 'Reality glass free grow involve foot provide. Bed create wish important simply tough if.\nNotice offer stage purpose event customer least. Cost nice find scientist official. Check product seem tell.', Decimal('28.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('434bf4a7-92ea-4f45-a5be-690b78493341'), 'Brenda Cherry', 'Yes kind specific network address. Each sister how go change ground door.\nSummer will station tonight. Think ready value modern think.', Decimal('18.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('18667aff-5092-41e5-8745-1bd93741269e'), 'David Smith', 'Network million for base common. Simply coach hospital total yard image.\nComputer decade yourself develop. Outside water a far lot.', Decimal('24.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('1a1157e9-5b5e-4170-ab7b-2b74237bf0aa'), 'Stefanie Dyer', 'Call book better particularly law contain red property. Feeling including true begin glass me. Partner task act campaign away. Dog partner commercial inside describe theory section.', Decimal('17.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('74c01103-3b52-46e4-ba81-eb90888a59f3'), 'Adam Ramsey', 'Evening wear yourself fire your. Nature young nation letter my seem.\nRest want information. Center ten certain.', Decimal('61.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('afe6c211-3630-4a84-8b5e-bdfd9f607eb8'), 'Chris French', 'Necessary computer single simply. Ready race machine see company during. Bring message later research prove. Sister want create citizen go.', Decimal('12.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('1399d9d0-855d-47db-bee0-255eb81e0e46'), 'John Taylor', 'Available great safe case.\nBenefit culture imagine popular involve. Finish general imagine design answer discover. Fire can training adult staff.\nHalf player degree mission.', Decimal('72.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('659a0aec-1497-4841-9cdb-bda36e794853'), 'Brett Chandler', 'Particular child perform away enough camera high. Effort nor possible since senior sort. Whatever benefit test blood bed catch.\nUnder white garden back build rule mission.', Decimal('98.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('59bfdb26-1c11-4e0b-b4ba-57d2608af42d'), 'Daniel Patterson MD', 'Laugh control country away. Professional bar thought me really room. Office machine which central way.', Decimal('40.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('2dcf708c-82eb-4189-a707-077cdb1e98f3'), 'Dale Valdez', 'Lead manager boy check carry drug. Color against enjoy success concern crime. Send deep anyone itself.\nBaby democratic quality appear total. Camera election about decade. Note agent son.', Decimal('3.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('15020db5-90ee-4285-b019-3fc974aa678f'), 'Jenna Blair', 'Reason order onto everyone. Cover produce sit someone.\nStore water set southern paper without each. Indicate threat student may analysis.', Decimal('50.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('54de35f2-bbf3-43b4-b6d1-f81b6abefb5c'), 'Stephen Mcfarland', 'Government power toward over usually with natural. Area fear home analysis marriage lead three. Positive marriage effort admit.\nSomebody mouth lay win. Style enough carry amount.', Decimal('56.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('d45984e5-5dac-4e6a-add9-f06a744dcf07'), 'Christopher Morton', 'Design represent window. Here like rise. Item produce Mr organization.\nRepresent and bit involve add born. Business central whom coach magazine present support tend. Place artist up purpose dog from.', Decimal('4.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('b9b28d08-9897-4b5b-8a56-bda434cab5cd'), 'Denise Spencer', 'Side effort since example act explain drop anyone. Heavy system receive join improve.\nThousand last bill democratic. Those admit project lose pull central.', Decimal('1.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('e08c7897-0fae-4c8b-9358-8add6e94298d'), 'James Vazquez Jr.', 'Class remain compare represent agree fish among. Soon lose trade practice study pattern. Beautiful state front game.\nSecurity much always yeah. Since behavior former cell money none particular.', Decimal('28.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('2ac624f9-35d4-4d71-be42-13d1374c8a06'), 'Robert Werner', 'Family billion art president remain almost.\nInvestment personal sense door cup. Practice sometimes grow young defense animal member baby. Sell lot look team contain. Response according grow also.', Decimal('87.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('924e032b-b983-4223-a879-59d9fd423790'), 'John Walker', 'Weight left painting since indeed property night. Ago truth contain husband back letter foot. Create character ball product sound move learn.', Decimal('37.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('e1d59ee9-3035-49d3-b4de-dbcb6afbb8b1'), 'Sarah Perry', 'Republican catch bar meeting agent these. Study mean next poor group.\nTheory threat one mouth compare ever agency. List involve girl high factor.', Decimal('9.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('49475e8d-a746-4cc1-9c41-1ba1b3469105'), 'Bianca Day DVM', 'More money hundred anything. This lot individual similar month represent one job.', Decimal('85.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('bb0039ba-62ff-492e-9d77-731664850818'), 'Christopher Long', 'Little scientist region fill box step later campaign. Professional manager full act list reason. Pick lot through option.\nCourt rule receive add. Easy morning computer catch.', Decimal('28.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('5d1a9b98-f472-4043-b19c-f7c7c6a39007'), 'Thomas Barnes', 'Event allow style all writer hot job. Type every off serve better benefit contain. Marriage table where character.\nIncluding land behind picture put dog. Hot now later measure ask.', Decimal('25.00'), True, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
# (UUID('143f84fd-5715-446b-bf67-ebbd0c3bec90'), 'Robert Rhodes', 'Western too half kitchen field animal. Southern really region north stage. I store goal we their.\nStudy analysis me natural just. Year newspaper cup city cup. Like worry hit sell.', Decimal('2.00'), False, datetime.datetime(2025, 10, 21, 21, 13, 37, 564488, tzinfo=datetime.timezone.utc))
